# %% [markdown]
# ## Visualize Router RSSI Data

# %%
# %matplotlib inline
import sys
sys.path.append('../scripts')
import matplotlib.pyplot as plt
import numpy as np
from tools import *
from localizer import *

# %%
hall_loc = localizer()
hall_loc.load_profile('./../scripts/network_profiles/hallway_profile.p')

def load_data(path, profile=None):
    wifi = []
    mag = []
    img = []
    xy = []
    coordinates = []
    file_count = 0
    if profile is not None:
        for file_name in os.listdir(path):
            if os.path.isfile(path + file_name):
                print('-- loading from {}'.format(file_name))
                file_coords = []
                with open(path + file_name, 'r') as f:
                    data = json.load(f)
                    show = True
                    points = 0
                    print('-- -- Length', len(data['datapoints']))
                    for point in data['datapoints']:
                        points += 1
                        x = float(point['x'])
                        y = float(point['y'])
                        xy.append([x, y])
                        if (x, y) not in file_coords:
                            file_coords.append((x, y))
                        mag.append([point['heading']/360.])
                        img1 = cv2.imread(point['img1'])
                        try:
                            img1 = preprocess_image(img1)
                        except:
                            print(points)
                            print(point['img1'])
                            return
                        img.append(img1)
                        wifi_row = []
                        for addr in profile:
                            try:
                                wifi_row.append(scale_rssi(float(point['access_points'][addr])))
                            except:
                                wifi_row.append(scale_rssi(-100.0))
                        wifi.append(wifi_row)
                coordinates.append(file_coords)
                print('-- -- Added {} datapoints'.format(points))
                file_count += 1
        print('Loaded {} files from {}'.format(file_count, path))
        xy = scale_xy(np.array(xy))
        return np.array(wifi), np.array(mag), np.float32(img), xy, coordinates
        
wifi, mag, images, y, coordinates = load_data('../datasets/', hall_loc.profile)
print(wifi.shape)
# Out:
# Creating new profile: /home/exx/jtf/localizer/scripts/network_profiles/hallway_profile.p
# ---------------------------------------------------------------------------
# KeyboardInterrupt                         Traceback (most recent call last)
# <ipython-input-7-5e3fed35a119> in <module>()
#       1 hall_loc = localizer()
# ----> 2 hall_loc.load_profile('/home/exx/jtf/localizer/scripts/network_profiles/hallway_profile.p')
#       3
#       4 def load_data(path, profile=None):
#       5     wifi = []
#
# ~/jtf/localizer/scripts/localizer.py in load_profile(self, profile_name)
#      40                 print('Loaded profile: {}'.format(profile_name))
#      41         else:
# ---> 42             self.make_profile(profile_name=profile_name)
#      43
#      44     def add_cells_to_profile(self, profile_name, num_add=5):
#
# ~/jtf/localizer/scripts/localizer.py in make_profile(self, profile_name, length)
#      27     def make_profile(self, profile_name, length=None):
#      28         print('Creating new profile: {}'.format(profile_name))
# ---> 29         profile = list(self.wifi.get_ap_group(ret_type='list')[:length,0])
#      30         with open(self.profile_path + profile_name + '.p', 'wb') as f:
#      31             pickle.dump(profile, f)
#
# ~/jtf/localizer/scripts/scanner.py in get_ap_group(self, ret_type)
#      27         ap_str = ''
#      28         while ap_str == '':
# ---> 29             ap_str = check_output('sudo iw dev wlan0 scan | egrep "signal|^BSS" | sed -e "s/\\tsignal: \(-[0-9]\{2\}\).*/\\1/" -e "s/^BSS \([0-9a-z:]\{17\}\)(on wlan0).*/\\1/" | awk \'{ORS = (NR % 2 == 0)? "\\n" : " "; print}\'', shell=True).decode()
#      30
#      31         ap_list = ap_str.splitlines()
#
# /usr/lib/python3.4/subprocess.py in check_output(timeout, *popenargs, **kwargs)
#     607     with Popen(*popenargs, stdout=PIPE, **kwargs) as process:
#     608         try:
# --> 609             output, unused_err = process.communicate(inputdata, timeout=timeout)
#     610         except TimeoutExpired:
#     611             process.kill()
#
# /usr/lib/python3.4/subprocess.py in communicate(self, input, timeout)
#     945                 self.stdin.close()
#     946             elif self.stdout:
# --> 947                 stdout = _eintr_retry_call(self.stdout.read)
#     948                 self.stdout.close()
#     949             elif self.stderr:
#
# /usr/lib/python3.4/subprocess.py in _eintr_retry_call(func, *args)
#     489     while True:
#     490         try:
# --> 491             return func(*args)
#     492         except InterruptedError:
#     493             continue
#
# KeyboardInterrupt:

# %% [markdown]
# *Display a graph of wifi signal over time for a given router*

# %%
routers = X.T
print(routers.shape)
plt.figure(figsize=(10, 9))
for router in routers:
    plt.plot(router)

plt.xlabel('time (s)')
plt.ylabel('RSSI %')
plt.grid(True)
plt.show()
# Out:
# (64, 600)

# %%
# this is showing the variation at a single point over 4 different sample times (varying t.o.d., angle)
x_pt = []
for i, point in enumerate(y):
    #print(point)
    if str(point) == '[ 0.  1.]':
        x_pt.append(X[i])
for i, point in enumerate(y):
    if str(point) == '[ 0.5  0.5]':
        x_pt.append(X[i])
x_pt = np.array(x_pt)
print(x_pt.shape)

routers2 = x_pt.T
print(routers2)
plt.figure(figsize=(16, 9))
for router in routers2[7:9]:
    plt.plot(router)

plt.xlabel('time (s)')
plt.grid(True)
plt.show()
# Out:
# (0,)
# []

# %%
split = np.array(np.split(routers, 9, axis=1))
split = np.reshape(split, (20, 9, 100))
print(split.shape)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# ~/.local/lib/python3.5/site-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     534     try:
# --> 535         len(indices_or_sections)
#     536     except TypeError:
#
# TypeError: object of type 'int' has no len()
#
# During handling of the above exception, another exception occurred:
#
# ValueError                                Traceback (most recent call last)
# <ipython-input-4-465b83846476> in <module>()
# ----> 1 split = np.array(np.split(routers, 9, axis=1))
#       2 split = np.reshape(split, (20, 9, 100))
#       3 print(split.shape)
#
# ~/.local/lib/python3.5/site-packages/numpy/lib/shape_base.py in split(ary, indices_or_sections, axis)
#     539         if N % sections:
#     540             raise ValueError(
# --> 541                 'array split does not result in an equal division')
#     542     res = array_split(ary, indices_or_sections, axis)
#     543     return res
#
# ValueError: array split does not result in an equal division

# %% [markdown]
# *Find maximum standard deviation for each router in each location*

# %%
stds = np.std(split, axis=2)
print(stds.shape)
print(np.amax(stds))
max_idx = np.unravel_index(np.argmax(stds), stds.shape)
print(stds[max_idx])
# Out:
# (20, 9)
# 6.59696900099
# 6.59696900099

# %%
plt.plot(split[max_idx])

# %% [markdown]
# ## Scaled Data

# %%
scaled = scale_inputs(routers)
print(scaled.shape)
# Out:
# (20, 900)

# %%
plt.figure(figsize=(16, 9))
for router in scaled:
    plt.plot(router)

plt.xlabel('time (s)')
plt.ylabel('RSSI (dB)')
plt.grid(True)
plt.show()

# %% [markdown]
# *Plot average RSSI per location*

# %%
scaled_split = scale_inputs(split)
print(scaled_split.shape)
avgs = np.mean(scaled_split, axis=2)
print(avgs.shape)
# Out:
# (20, 9, 100)
# (20, 9)

# %%
for i, cell in enumerate(avgs):
    plt.plot(cell)
plt.show()
